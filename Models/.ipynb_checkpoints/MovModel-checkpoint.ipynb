# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.src.models import Sequential
from keras.src.layers import Dense
from keras.src.utils import to_categorical
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("./Data/File_Acc_Tel_v1.csv")

# %%
# Separazione delle feature e della label
X = data[['AccX', 'AccY', 'AccZ']].values  # Feature: valori di accelerazione
y = data['is_moving'].values                   # Target: etichette

# %%
# Divisione del dataset in set di addestramento e test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle=True)

# %%
# Standardizzazione dei dati
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Conversione delle etichette in formato categorico
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
# Creazione del modello Sequential
model = Sequential([
    Dense(64, activation='relu', input_shape=(3,)),   # Primo strato con 64 unità e funzione di attivazione ReLU
    Dense(32, activation='relu'),                     # Secondo strato nascosto con 32 unità
    Dense(y_train_cat.shape[1], activation='softmax') # Strato output con attivazione softmax (classificazione)
])
# Out:
# c:\Users\aless\miniconda3\envs\ModelliAle\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilazione del modello
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train_cat, epochs=100, batch_size=64, validation_split=0.2)

# Grafico della loss durante le epoche
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss Training')
plt.plot(history.history['val_loss'], label='Loss Validation')
plt.title('Loss durante le epoche')
plt.xlabel('Epoche')
plt.ylabel('Loss')
plt.legend()

# Grafico dell'accuracy durante le epoche
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy Training')
plt.plot(history.history['val_accuracy'], label='Accuracy Validation')
plt.title('Accuracy durante le epoche')
plt.xlabel('Epoche')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7393 - loss: 0.5946 - val_accuracy: 0.8602 - val_loss: 0.4268
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8376 - loss: 0.4414 - val_accuracy: 0.8666 - val_loss: 0.3521
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8613 - loss: 0.3609 - val_accuracy: 0.8869 - val_loss: 0.3197
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8626 - loss: 0.3346 - val_accuracy: 0.8869 - val_loss: 0.3058
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8644 - loss: 0.3318 - val_accuracy: 0.8882 - val_loss: 0.3012
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8780 - loss: 0.2991 - val_accuracy: 0.8958 - val_loss: 0.3101
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8681 - loss: 0.3268 - val_accuracy: 0.8869 - val_loss: 0.2968
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8635 - loss: 0.3246 - val_accuracy: 0.8920 - val_loss: 0.3019
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8640 - loss: 0.3213 - val_accuracy: 0.8996 - val_loss: 0.3042
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8729 - loss: 0.3121 - val_accuracy: 0.8882 - val_loss: 0.2988
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8691 - loss: 0.3064 - val_accuracy: 0.8958 - val_loss: 0.3037
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8637 - loss: 0.3344 - val_accuracy: 0.8895 - val_loss: 0.2950
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8746 - loss: 0.3017 - val_accuracy: 0.8895 - val_loss: 0.2969
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8761 - loss: 0.3112 - val_accuracy: 0.8895 - val_loss: 0.2944
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8789 - loss: 0.2958 - val_accuracy: 0.8920 - val_loss: 0.2954
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8807 - loss: 0.2940 - val_accuracy: 0.8920 - val_loss: 0.2936
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8869 - loss: 0.2818 - val_accuracy: 0.8971 - val_loss: 0.2866
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8937 - loss: 0.2806 - val_accuracy: 0.8945 - val_loss: 0.2842
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8953 - loss: 0.2687 - val_accuracy: 0.8958 - val_loss: 0.2867
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.2797 - val_accuracy: 0.8958 - val_loss: 0.2847
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8889 - loss: 0.2849 - val_accuracy: 0.8971 - val_loss: 0.2860
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8867 - loss: 0.2875 - val_accuracy: 0.8971 - val_loss: 0.2848
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8941 - loss: 0.2749 - val_accuracy: 0.8958 - val_loss: 0.2873
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8861 - loss: 0.2828 - val_accuracy: 0.8983 - val_loss: 0.2829
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8890 - loss: 0.2769 - val_accuracy: 0.9034 - val_loss: 0.2932
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8938 - loss: 0.2825 - val_accuracy: 0.8983 - val_loss: 0.2874
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9037 - loss: 0.2602 - val_accuracy: 0.8958 - val_loss: 0.2856
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8898 - loss: 0.2909 - val_accuracy: 0.8958 - val_loss: 0.2846
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8861 - loss: 0.2880 - val_accuracy: 0.8996 - val_loss: 0.2879
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8893 - loss: 0.2770 - val_accuracy: 0.8971 - val_loss: 0.2850
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8901 - loss: 0.2821 - val_accuracy: 0.8945 - val_loss: 0.2858
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8958 - loss: 0.2693 - val_accuracy: 0.9022 - val_loss: 0.2890
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8944 - loss: 0.2727 - val_accuracy: 0.8971 - val_loss: 0.2856
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8926 - loss: 0.2677 - val_accuracy: 0.9009 - val_loss: 0.2871
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8980 - loss: 0.2639 - val_accuracy: 0.8983 - val_loss: 0.2887
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8883 - loss: 0.2860 - val_accuracy: 0.8895 - val_loss: 0.2887
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8948 - loss: 0.2708 - val_accuracy: 0.8958 - val_loss: 0.2854

# %%
# Valutazione del modello
y_pred_cat = model.predict(X_test)
y_pred = y_pred_cat.argmax(axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Accuratezza e report di classificazione
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuratezza del modello:", accuracy)
print("\nReport di classificazione:\n", report)
# Out:
# Accuratezza del modello: 0.8983739837398373
#
# Report di classificazione:
#                precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89       448
#         True       0.93      0.88      0.90       536
#
#     accuracy                           0.90       984
#    macro avg       0.90      0.90      0.90       984
# weighted avg       0.90      0.90      0.90       984

# %%
y_test_pred = np.argmax(model.predict(X_test), axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
giuste, sbagliate = 0, 0
for y_pred, y in zip(y_test_pred, y_test):
    if y_pred == y:
        giuste += 1
    else:
        sbagliate +=1

print(f"Giuste= {giuste}     Sbagliate= {sbagliate}")
# Out:
# Giuste= 884     Sbagliate= 100

# %%
model.save("./MyModels/ModelTelv1.keras", overwrite=False)
# Out:
# [TIP] Next time specify overwrite=True!
